# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6FmuLVTzHo8XkZwuBUyO")
project = rf.workspace("joseph-nelson").project("mask-wearing")
version = project.version(19)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Mask-Wearing-19 in yolov8:: 100%|██████████| 3880/3880 [00:01<00:00, 3812.60it/s]

# %%
import os
len(os.listdir('/content/Mask-Wearing-19/train/images'))
# Out:
# 1366

# %%
len(os.listdir('/content/Mask-Wearing-19/test/images'))
# Out:
# 200

# %%
len(os.listdir('/content/Mask-Wearing-19/valid/images'))
# Out:
# 368

# %%
# import os
# import shutil


# def createTestDatset(source_dir,destination_dir):
#   # Define your source and destination directories
#   # source_dir = '/content/Fire-Detection-1/train'
#   # destination_dir = '/content/Fire-Detection-1/test'

#   # Create the destination directory if it doesn't exist
#   os.makedirs(destination_dir, exist_ok=True)

#   # Get a list of all files in the source directory
#   all_files = sorted(os.listdir(source_dir))

#   # Get the last 2000 files
#   files_to_move = all_files[-2000:]

#   # Move the files
#   for file_name in files_to_move:
#       source_file = os.path.join(source_dir, file_name)
#       destination_file = os.path.join(destination_dir, file_name)
#       shutil.move(source_file, destination_file)

#   print(f'Moved {len(files_to_move)} files to {destination_dir}')


# createTestDatset('/content/Fire-Detection-1/train/images','/content/Fire-Detection-1/test/images')
# Out:
# Moved 2000 files to /content/Fire-Detection-1/test/images

# %%
# createTestDatset('/content/Fire-Detection-1/train/labels','/content/Fire-Detection-1/test/labels')
# Out:
# Moved 2000 files to /content/Fire-Detection-1/test/labels

# %%
# import os
# len(os.listdir('/content/Fire-Detection-1/test/images'))
# Out:
# 2000

# %%
# import os
# len(os.listdir('/content/Fire-Detection-1/train/images'))
# Out:
# 6939

# %%
# import os
# len(os.listdir('/content/Fire-Detection-1/train/labels'))
# Out:
# 6939

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.2/872.2 kB 24.0 MB/s eta 0:00:00

# %%
# !mkdir -p {HOME}/weights

# %%
# !wget -P {HOME}/weights -q https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt
# !wget -P {HOME}/weights -q https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt
# !wget -P {HOME}/weights -q https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8m.pt
# !wget -P {HOME}/weights -q https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8l.pt
# !wget -P {HOME}/weights -q https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt

# %%
# !ls -lh {HOME}/weights
# Out:
# total 292M
# -rw-r--r-- 1 root root  84M Jul 10 14:37 yolov8l.pt
# -rw-r--r-- 1 root root  50M Jul 10 14:38 yolov8m.pt
# -rw-r--r-- 1 root root 6.3M Jul 10 14:31 yolov8n.pt
# -rw-r--r-- 1 root root  22M Jul 10 14:32 yolov8s.pt
# -rw-r--r-- 1 root root 131M Jul 10 14:26 yolov8x.pt

# %%
# !mkdir -p {HOME}/data

# %%
# SOURCE_IMAGE = "sample_image1.jpg"

# """## **Detection with pre-trained model**"""

from IPython.display import Image

Image(filename='/content/data/sample_image1.jpg', height=400)

# %%
# %cd {HOME}
# !yolo task=detect mode=predict conf=0.25 save=True model={HOME}/weights/yolov8s.pt source=/content/data/sample_image1.jpg
# Out:
# /content
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/data/sample_image1.jpg: 640x640 2 persons, 16.5ms
# Speed: 12.8ms preprocess, 16.5ms inference, 809.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model={HOME}/weights/yolov8n.pt source=/content/data/sample_image1.jpg
# Out:
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/data/sample_image1.jpg: 640x640 2 persons, 1 book, 7.9ms
# Speed: 3.7ms preprocess, 7.9ms inference, 537.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model={HOME}/weights/yolov8m.pt source=/content/data/sample_image1.jpg
# Out:
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# image 1/1 /content/data/sample_image1.jpg: 640x640 1 person, 37.3ms
# Speed: 3.4ms preprocess, 37.3ms inference, 821.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model={HOME}/weights/yolov8l.pt source=/content/data/sample_image1.jpg
# Out:
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43,668,288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/1 /content/data/sample_image1.jpg: 640x640 1 person, 62.9ms
# Speed: 3.6ms preprocess, 62.9ms inference, 592.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model={HOME}/weights/yolov8x.pt source=/content/data/sample_image1.jpg
# Out:
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
#
# image 1/1 /content/data/sample_image1.jpg: 640x640 1 person, 90.0ms
# Speed: 5.4ms preprocess, 90.0ms inference, 865.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

model = YOLO(f'{HOME}/weights/yolov8x.pt')
results = model(source=f'/content/data/sample_image1.jpg', conf=0.25)

print(results[0].boxes.xyxy)
print(results[0].boxes.conf)
print(results[0].boxes.cls)
# Out:
# image 1/1 /content/data/sample_image1.jpg: 640x640 1 person, 82.3ms
# Speed: 3.5ms preprocess, 82.3ms inference, 475.3ms postprocess per image at shape (1, 3, 640, 640)
# tensor([[   2.1351,   15.6777,  615.1727, 1402.5875]], device='cuda:0')
# tensor([0.9567], device='cuda:0')
# tensor([0.], device='cuda:0')

# %%
# !pip install supervision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 6.7 MB/s eta 0:00:00
# ...

# %%
import cv2
import supervision as sv
from ultralytics import YOLO

model = YOLO(f'{HOME}/weights/yolov8l.pt')
image = cv2.imread(f'/content/data/sample_image1.jpg')
results = model(image)[0]
detections = sv.Detections.from_ultralytics(results)

bounding_box_annotator = sv.BoundingBoxAnnotator()
label_annotator = sv.LabelAnnotator()

annotated_image = bounding_box_annotator.annotate(
    scene=image, detections=detections)
annotated_image = label_annotator.annotate(
    scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
# Out:
# 0: 640x640 1 person, 58.3ms
# Speed: 4.8ms preprocess, 58.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# SupervisionWarnings: BoundingBoxAnnotator is deprecated: `BoundingBoxAnnotator` is deprecated and has been renamed to `BoxAnnotator`. `BoundingBoxAnnotator` will be removed in supervision-0.26.0.

# %%
dataset.location
# Out:
# '/content/Mask-Wearing-19'

# %%
# !yolo task=detect mode=train epochs=15 batch=6 plots=True \
model={HOME}/weights/yolov8l.pt \
data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
def download_runs_folder():
    folder_to_zip = 'runs'
    output_zip = 'runs.zip'
    # !zip -r {output_zip} {folder_to_zip}

download_runs_folder()
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/predict/ (stored 0%)
#   adding: runs/detect/predict/sample_image1.jpg (deflated 14%)
#   adding: runs/detect/predict5/ (stored 0%)
#   adding: runs/detect/predict5/sample_image1.jpg (deflated 11%)
#   adding: runs/detect/predict2/ (stored 0%)
#   adding: runs/detect/predict2/sample_image1.jpg (deflated 16%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/results.png (deflated 7%)
#   adding: runs/detect/train/PR_curve.png (deflated 15%)
#   adding: runs/detect/train/labels.jpg (deflated 30%)
#   adding: runs/detect/train/val_batch2_pred.jpg (deflated 8%)
#   adding: runs/detect/train/R_curve.png (deflated 11%)
#   adding: runs/detect/train/confusion_matrix_normalized.png (deflated 32%)
#   adding: runs/detect/train/train_batch2.jpg (deflated 9%)
#   adding: runs/detect/train/val_batch1_pred.jpg (deflated 8%)
#   adding: runs/detect/train/train_batch1.jpg (deflated 15%)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1725087415.10e2d9b137a8.3607.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1140.jpg  val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch1141.jpg  val_batch2_pred.jpg
# labels.jpg					    train_batch1142.jpg  weights
# P_curve.png					    train_batch1.jpg
# PR_curve.png					    train_batch2.jpg

# %%
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %%
Image(filename=f'{HOME}/runs/detect/train/train_batch2.jpg', width=600)

# %%
"""## **Inference on Video**"""

# !yolo task=detect mode=predict conf=0.25 save=True model=/content/runs/detect/train2/weights/best.pt source=/content/data/sample_video1.mp4

# %%
"""### **Inference Image**"""

# !yolo task=detect mode=predict conf=0.25 save=True model=/content/runs/detect/train2/weights/best.pt source=/content/data/sample_image1.jpg
# Out:
# Ultralytics YOLOv8.2.45 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 268 layers, 43608921 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/data/sample_image1.jpg: 448x640 1 fire, 157.9ms
# Speed: 4.9ms preprocess, 157.9ms inference, 566.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import files
import os

def detectFromImage():
  # Upload file
  uploaded = files.upload()

  # Assuming a single file is uploaded, get the file name
  source_image = list(uploaded.keys())[0]

  # Verify the file path
  print(f"Source image: {source_image}")

  # Run the YOLO command (replace with appropriate call in your notebook if necessary)
  # !yolo task=detect mode=predict conf=0.70 save=True model=/content/runs/detect/train/weights/best.pt source={source_image}

# %%
detectFromImage()
# Out:
#      <input type="file" id="files-d688ea8f-81d2-4627-a73c-f1dd17d00d1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d688ea8f-81d2-4627-a73c-f1dd17d00d1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/content/runs/detect/train/weights/best.pt source=/content/www.ubuy.com.jpg
# Out:
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/www.ubuy.com.jpg: 640x576 3 masks, 63.4ms
# Speed: 3.1ms preprocess, 63.4ms inference, 572.5ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict conf=0.50 save=True model=/content/runs/detect/train/weights/best.pt source=/content/sdfsdfsdfdsf.jpg
# Out:
# Ultralytics YOLOv8.2.84 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/1 /content/sdfsdfsdfdsf.jpg: 448x640 3 masks, 64.6ms
# Speed: 2.4ms preprocess, 64.6ms inference, 531.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict13
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO
import cv2


# load yolov8 model
# model = YOLO('yolov8n.pt')
model = YOLO('runs/detect/train/weights/best.pt')

# load video
video_path = 0
cap = cv2.VideoCapture(video_path)

ret = True
# read frames
while ret:
    ret, frame = cap.read()

    if ret:

        # detect objects
        # track objects
        results = model.track(frame, persist=True)

        # plot results
        # cv2.rectangle
        # cv2.putText
        frame_ = results[0].plot()

        # visualize
        cv2.imshow('frame', frame_)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
# Out:
# 0: 480x640 1 person, 1 chair, 142.5ms
# Speed: 7.0ms preprocess, 142.5ms inference, 860.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 87.0ms
# Speed: 3.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 91.1ms
# Speed: 1.0ms preprocess, 91.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 92.0ms
# Speed: 2.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 91.6ms
# Speed: 2.0ms preprocess, 91.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 91.1ms
# Speed: 1.0ms preprocess, 91.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
